# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df_train = pd.read_csv("E:/DataScience_Study/3months/Data-Lit/week4-Regression/4.7_housePrice/train.csv")
df_test = pd.read_csv("E:/DataScience_Study/3months/Data-Lit/week4-Regression/4.7_housePrice/test.csv")

# %%
df_train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_test.head(5)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
sns.scatterplot(x='MSSubClass', y='SalePrice', data=df_train)

# %%
sns.scatterplot(x='LotArea', y='SalePrice', data=df_train)

# %%
sns.scatterplot(x='GarageCars', y='SalePrice', data=df_train)

# %%
sns.scatterplot(x='HouseStyle', y='SalePrice', data=df_train)

# %%
sns.scatterplot(x='OverallQual', y='SalePrice', data=df_train) #This one: price is increasing with overqual

# %%
sns.scatterplot(x='YearRemodAdd', y='SalePrice', data=df_train) #This one: price is increasing with x

# %%
sns.scatterplot(x='2ndFlrSF', y='SalePrice', data=df_train) #This one: price is increasing with x

# %%
sns.scatterplot(x='GrLivArea', y='SalePrice', data=df_train)

# %%
sns.scatterplot(x='TotRmsAbvGrd', y='SalePrice', data=df_train)

# %%
sns.scatterplot(x='TotalBsmtSF', y='SalePrice', data=df_train)

# %%
sns.scatterplot(x='YearBuilt', y='SalePrice', data=df_train)

# %%
sns.scatterplot(x='BsmtUnfSF', y='SalePrice', data=df_train) # not woth

# %%
sns.boxplot(y='Neighborhood', x='SalePrice', data=df_train )

# %% [markdown]
# ##From above graphs we conclude that OverallCond, yearbuilt, yearremodeAdd, totalBsmtSF, 1stFlrSF GrLivArea are more important

# %%
#descriptive statistics summary : First thing First Analyse dependant variable:
df_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# From above observation we can see that min price is > 0 no wrong values

# %%
sns.distplot(df_train['SalePrice'])
# Out:
# C:\Users\ikd\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# From above distribution :
# distribution deviates from normal
# postive skewness
# peakdeness

# %%
print("Skewness: %f" % df_train['SalePrice'].skew())
# Out:
# Skewness: 1.882876

# %%
print("Kurtosis: %f" % df_train['SalePrice'].kurt())
# Out:
# Kurtosis: 6.536282

# %% [markdown]
# ##ReletionShip With Numerical Variables

# %%
sns.scatterplot(x='GrLivArea', y='SalePrice', data=df_train)

# %% [markdown]
# ##Seems that GrliveArea and SalesPrice have linear Relationship

# %%
sns.scatterplot(x='TotalBsmtSF', y='SalePrice', data=df_train)

# %% [markdown]
# ##looks like linear exonential reletionship above: sometimes TotalBsmtSF gives zero credit to saleprice

# %%
##ReletionShip With categorical Variables

# %%
sns.boxplot(x='OverallQual', y='SalePrice', data=df_train )

# %%
f, ax = plt.subplots(figsize=(12, 9))
sns.boxplot(x='YearBuilt', y='SalePrice', data=df_train )

# %% [markdown]
# #From Nummerical Features we got to know that it in linear relation and from categorical boxplot shoes how sales price increases with overall quality.

# %% [markdown]
# We just analysed four variables, but there are many other that we should analyse. The trick here seems to be the choice of the right features (feature selection) and not the definition of complex relationships between them (feature engineering).

# %%
# will understand the reletion ship between features using heap and corelation
corrmat = df_train.corr()
print(corrmat)
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, square=True)

# %% [markdown]
# From above graph Sales Price, OverallQual and GrlivArea are highly corelated but there are alos many varibles. But, TotalBsmtSF and 1stFlorSF are corelated so they generates multicolinearity also Garagex varibales doing same.

# %%
#salesPrice corelation Matrix
k = 10 # no. of varibales for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df_train[cols].values.T)
f, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1.25)
sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)

# %% [markdown]
# Scatter plots between 'SalePrice' and correlated variables.

# %%
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols], height=2.5)

# %% [markdown]
# from above graph we can see reletion between various features:
# TotalBsmtSF vs GrLivArea shows us that area increases bsmt also increases upto certain point. As bsmt area is always smaller than total area and it should not increase with increase in GrivArea.
# We can also see that SalesPrice vs YearBuilt as year is increasing price also increasing

# %% [markdown]
# # Missing Data
# Important questions when thinking about missing data:
#
# How prevalent is the missing data?
# Is missing data random or does it have a pattern?
# because: missing data leads to reduction of sampl sizes also to check whether missing data is not bias or have any inconvient hidden truth.

# %%
total = df_train.isnull().sum().sort_values(ascending = False)
total

# %%
perc = (df_train.isnull().sum()/df_train.isnull().count() * 100).sort_values(ascending=False)
perc
# Out:
# PoolQC           99.520548
# MiscFeature      96.301370
# Alley            93.767123
# Fence            80.753425
# FireplaceQu      47.260274
# LotFrontage      17.739726
# GarageCond        5.547945
# GarageType        5.547945
# GarageYrBlt       5.547945
# GarageFinish      5.547945
# GarageQual        5.547945
# BsmtExposure      2.602740
# BsmtFinType2      2.602740
# BsmtFinType1      2.534247
# BsmtCond          2.534247
# BsmtQual          2.534247
# MasVnrArea        0.547945
# MasVnrType        0.547945
# Electrical        0.068493
# Utilities         0.000000
# YearRemodAdd      0.000000
# MSSubClass        0.000000
# Foundation        0.000000
# ExterCond         0.000000
# ExterQual         0.000000
# Exterior2nd       0.000000
# Exterior1st       0.000000
# RoofMatl          0.000000
# RoofStyle         0.000000
# YearBuilt         0.000000
#                    ...
# GarageArea        0.000000
# PavedDrive        0.000000
# WoodDeckSF        0.000000
# ...

# %%
missing_data = pd.concat([total, perc], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total    Percent
# PoolQC         1453  99.520548
# MiscFeature    1406  96.301370
# Alley          1369  93.767123
# Fence          1179  80.753425
# FireplaceQu     690  47.260274
# LotFrontage     259  17.739726
# GarageCond       81   5.547945
# GarageType       81   5.547945
# GarageYrBlt      81   5.547945
# GarageFinish     81   5.547945
# GarageQual       81   5.547945
# BsmtExposure     38   2.602740
# BsmtFinType2     38   2.602740
# BsmtFinType1     37   2.534247
# BsmtCond         37   2.534247
# BsmtQual         37   2.534247
# MasVnrArea        8   0.547945
# MasVnrType        8   0.547945
# Electrical        1   0.068493
# Utilities         0   0.000000

# %% [markdown]
# We should consider that if more than 15% data is missing we shold delete it and pertend like they never existed. so from above --there are lot of variables : now question will come like ww may loose missing data. Answer is no. Because from above graphs we saw that these are least important varibales.
# -Now about GarageX variables : they all have same set of missing values so i think it is same set of observations : So will delete it same oes with BsmtX variables.
# -about MasVnrType and MasVnrArea are not important as we conseiderd grivArea and all so we delete these also
# -Finally we have only one missing observation Electrical so will delete observation and keep variable.

# %%
#dealing with missing data
df_train = df_train.drop((missing_data[missing_data['Total'] > 1]).index,1)

# %%
df_train = df_train.drop(df_train.loc[df_train['Electrical'].isnull()].index)

# %%
df_train.isnull().sum().max()
# Out:
# 0

# %% [markdown]
# # Outliers Handling
# Because outliers can affect our models and can be a valuable source of information, providing us insights about specific behaviours.

# %% [markdown]
# Normality: Means data should look like normally distributed: although normality is not important if sampllw size is >
# 200. but if we solve normality lot of other problems like heteroscedacity will solve automatically.

# %%
#Plot the distribution with a histogram and maximum likelihood gaussian distribution fit:
from scipy.stats import norm
sns.distplot(df_train['SalePrice'], fit=norm)
# Out:
# C:\Users\ikd\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from scipy import stats
stats.probplot(df_train['SalePrice'], plot=plt)
# Out:
# ((array([-3.30494753, -3.04772643, -2.90468264, ...,  2.90468264,
#           3.04772643,  3.30494753]),
#   array([ 34900,  35311,  37900, ..., 625000, 745000, 755000], dtype=int64)),
#  (74187.860388132, 180930.39479095273, 0.9320032714937404))

# %% [markdown]
# From above graphs we can see that sales price is not normal It shows peakdeness and positive skewness
#  in case of positive skewness, log transformations usually works well.

# %%
#applying log transformations:
df_train['SalePrice'] = np.log(df_train['SalePrice'])

# %%
sns.distplot(df_train['SalePrice'], fit=norm)
# Out:
# C:\Users\ikd\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
stats.probplot(df_train['SalePrice'], plot=plt)
# Out:
# ((array([-3.30494753, -3.04772643, -2.90468264, ...,  2.90468264,
#           3.04772643,  3.30494753]),
#   array([10.46024211, 10.47194981, 10.54270639, ..., 13.34550693,
#          13.5211395 , 13.53447303])),
#  (0.3984035944009483, 12.024047688135333, 0.9953872421515823))

# %% [markdown]
# Now check what's going on with 'GrLivArea'.

# %%
sns.distplot(df_train['GrLivArea'], fit=norm)
# Out:
# C:\Users\ikd\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
stats.probplot(df_train['GrLivArea'], plot=plt)
# Out:
# ((array([-3.30494753, -3.04772643, -2.90468264, ...,  2.90468264,
#           3.04772643,  3.30494753]),
#   array([ 334,  438,  480, ..., 4476, 4676, 5642], dtype=int64)),
#  (506.8582122788622, 1515.5469499657302, 0.9626561624641505))

# %%
df_train['GrLivArea'] = np.log(df_train['GrLivArea'])

# %%
sns.distplot(df_train['GrLivArea'], fit=norm)
# Out:
# C:\Users\ikd\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
stats.probplot(df_train['GrLivArea'], plot=plt)
# Out:
# ((array([-3.30494753, -3.04772643, -2.90468264, ...,  2.90468264,
#           3.04772643,  3.30494753]),
#   array([5.81114099, 6.08221891, 6.1737861 , ..., 8.40648507, 8.45019832,
#          8.63799389])),
#  (0.33345646260437284, 7.26779346610195, 0.9977274878020771))

# %%
sns.distplot(df_train['TotalBsmtSF'], fit=norm)
# Out:
# C:\Users\ikd\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
stats.probplot(df_train['TotalBsmtSF'], plot=plt)
# Out:
# ((array([-3.30494753, -3.04772643, -2.90468264, ...,  2.90468264,
#           3.04772643,  3.30494753]),
#   array([   0,    0,    0, ..., 3200, 3206, 6110], dtype=int64)),
#  (420.0209673456654, 1057.8910212474298, 0.9562744435229183))

# %% [markdown]
# from above observations we have : in general, presents skewness.
# A significant number of observations with value zero (houses without basement).
# A big problem because the value zero doesn't allow us to do log transformations

# %%
x = np.log(df_train[df_train['TotalBsmtSF'] > 0]) # we cant apply log on zero calues
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-226-564bc9fd76fb> in <module>()
# ----> 1 x = np.log(df_train[df_train['TotalBsmtSF'] > 0]) # we cant apply log on zero calues
#
# AttributeError: 'int' object has no attribute 'log'

# %%
df_train['HasBsmt'] = pd.Series(len(df_train['TotalBsmtSF']), index=df_train.index)

# %%
df_train['HasBsmt'] = 0

# %%
df_train.loc[df_train['TotalBsmtSF'] > 0, 'HasBsmt'] = 1

# %%
#transform data
df_train.loc[df_train['HasBsmt']==1,'TotalBsmtSF'] = np.log(df_train['TotalBsmtSF'])
# Out:
# C:\Users\ikd\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
sns.distplot(df_train[df_train['TotalBsmtSF']>0]['TotalBsmtSF'], fit=norm)
# Out:
# C:\Users\ikd\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
res = stats.probplot(df_train[df_train['TotalBsmtSF']>0]['TotalBsmtSF'], plot=plt)

# %%
df_train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotArea            int64
# Street            object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF      float64
#                   ...
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea        float64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# ...

# %%
 df_train = pd.get_dummies(df_train)

# %%
df_train.shape
# Out:
# (1459, 223)

# %%
from sklearn.model_selection import train_test_split
X = df_train.drop('SalePrice', axis=1) 
y = df_train['SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=60)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def predict_metrics(model, x, y):
    pred = model.predict(x)
    mse = mean_squared_error(y, pred)
    mae = mean_absolute_error(y, pred)
    r2 = r2_score(y, pred)
    return mse, mae, r2

# %% [markdown]
# # linear Regression

# %%
# Higher dimensions.
from sklearn.linear_model import LinearRegression

linR = LinearRegression(normalize=True).fit(X_train, y_train)
multi_intercept = linR.intercept_
multi_coeffs = dict(zip(X, linR.coef_))

print("Intercept: ", multi_intercept)
#print("coefficients: ", multi_coeffs)
# Out:
# Intercept:  14055165035576.557

# %%
# calculate error matrix:
mse_train, mae_train, r2_train = predict_metrics(linR, X_train, y_train)
print("train mse:", mse_train," train mae:", mae_train," R2-train", r2_train)
# Out:
# train mse: 0.007552210978493365  train mae: 0.06229678590745936  R2-train 0.9507203488055316

# %%
mse_test, mae_test, r2_test = predict_metrics(linR, X_test, y_test)
print("test mse:", mse_test," test mae:", mae_test," R2-test", r2_test)
# Out:
# test mse: 4.1466155223678426e+24  test mae: 176336920367.84628  R2-test -2.252077248304732e+25

# %% [markdown]
# # Ridge regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

alpha = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]
ridge = Ridge()
parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]}

ridge_regressor = GridSearchCV(ridge, parameters, scoring='neg_mean_squared_error', cv=5)
ridge_regressor.fit(X_train, y_train)
# Out:
# C:\Users\ikd\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.087403e-21
#   overwrite_a=True).T
# C:\Users\ikd\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.025387e-21
#   overwrite_a=True).T
# C:\Users\ikd\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.233348e-21
#   overwrite_a=True).T
# C:\Users\ikd\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number9.061617e-22
# ...

# %%
ridge_regressor.best_score_
# Out:
# -0.015071985846793466

# %%
ridge_regressor.best_params_
# Out:
# {'alpha': 1}

# %%
best_model = ridge_regressor.best_estimator_

mse_train, mae_train, r2_train = predict_metrics(ridge_regressor, X_train, y_train)
print("train mse:", mse_train," train mae:", mae_train," R2-train", r2_train)
# Out:
# train mse: 0.00800451241213273  train mae: 0.06401227429798714  R2-train 0.9477689936397424

# %%
mse_test, mae_test, r2_test = predict_metrics(ridge_regressor, X_test, y_test)
print("test mse:", mse_test," test mae:", mae_test," R2-test", r2_test)
# Out:
# test mse: 0.03590297474424205  test mae: 0.09864971397307139  R2-test 0.8050065839675544

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import Lasso

alpha = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]
parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]}

lasso = Lasso()

lasso_regressor = GridSearchCV(lasso, parameters, scoring='neg_mean_squared_error', cv=5 )
lasso_regressor.fit(X_train, y_train)
# Out:
# C:\Users\ikd\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ikd\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\ikd\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
lasso_regressor.best_params_
# Out:
# {'alpha': 0.0001}

# %%
lasso_regressor.best_score_
# Out:
# -0.014828687776900782

# %%
df_test = df_test.drop(['Saleprice'], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-315-6d09b138cb88> in <module>()
# ----> 1 df_test = df_test.drop(['Saleprice'], inplace=True, axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
total = df_test.isnull().sum().sort_values(ascending = False)
total
# Out:
# PoolQC           1456
# MiscFeature      1408
# Alley            1352
# Fence            1169
# FireplaceQu       730
# LotFrontage       227
# GarageCond         78
# GarageQual         78
# GarageYrBlt        78
# GarageFinish       78
# GarageType         76
# BsmtCond           45
# BsmtQual           44
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinType2       42
# MasVnrType         16
# MasVnrArea         15
# MSZoning            4
# BsmtHalfBath        2
# Utilities           2
# Functional          2
# BsmtFullBath        2
# BsmtFinSF2          1
# BsmtFinSF1          1
# Exterior2nd         1
# BsmtUnfSF           1
# TotalBsmtSF         1
# SaleType            1
# Exterior1st         1
#                  ...
# OverallQual         0
# SaleCondition       0
# Heating             0
# ExterQual           0
# TotRmsAbvGrd        0
# YrSold              0
# MoSold              0
# MiscVal             0
# PoolArea            0
# ScreenPorch         0
# ...

# %%
best_model = lasso_regressor.best_estimator_

mse_train, mae_train, r2_train = predict_metrics(lasso_regressor, X_train, y_train)
print("train mse:", mse_train," train mae:", mae_train," R2-train", r2_train)
# Out:
# train mse: 0.0078722182367374  train mae: 0.06446500806597119  R2-train 0.9486322389644701

# %%
mse_test, mae_test, r2_test = predict_metrics(lasso_regressor, X_test, y_test)
print("test mse:", mse_test," test mae:", mae_test," R2-test", r2_test)
# Out:
# test mse: 0.04291520385351825  test mae: 0.10119547523396626  R2-test 0.7669223160827825

# %%
test_X = df_test.drop('SalePrice', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-317-5b2ea215ab40> in <module>()
# ----> 1 test_X = df_test.drop('SalePrice', axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...
